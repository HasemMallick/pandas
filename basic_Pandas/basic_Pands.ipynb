# %% [markdown]
# ## Basic of pandas

# %%
# import pandas
import pandas as pd

# %%
# Check pandas version 
print(pd.__version__)
# Out:
# 2.2.2

# %%
# create a dataset
dataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

# create a dataframe
df = pd.DataFrame(dataset)
df.shape
df.head()
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
# Read a csv file in Pandas
csv = pd.read_csv("titanic data.csv", delimiter=",")
csv
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                        Graham, Miss Margaret Edith  female  19.0      0
# 888            Johnston, Miss Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 13 columns]

# %%
# csv file to DF
df = pd.DataFrame(csv)
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                        Graham, Miss Margaret Edith  female  19.0      0
# 888            Johnston, Miss Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 13 columns]

# %%
# shpae of the DF
df.shape
# Out:
# (891, 13)

# %%
# heade of the DF
df.head(4)
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
# tial of of df
df.tail(4)
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                         Name     Sex   Age  SibSp  Parch  \
# 887              Graham, Miss Margaret Edith  female  19.0      0      0
# 888  Johnston, Miss Catherine Helen "Carrie"  female   NaN      1      2
# 889                    Behr, Mr. Karl Howell    male  26.0      0      0
# 890                      Dooley, Mr. Patrick    male  32.0      0      0
#
#          Ticket   Fare Cabin Embarked
# 887      112053  30.00   B42        S
# 888  W./C. 6607  23.45   NaN        S
# 889      111369  30.00  C148        C
# 890      370376   7.75   NaN        Q

# %%
# stat of the df
df.describe()
# Out:
#        Unnamed: 0  PassengerId    Survived      Pclass         Age  \
# count  891.000000   891.000000  891.000000  891.000000  714.000000
# mean   445.000000   446.000000    0.383838    2.308642   29.699118
# std    257.353842   257.353842    0.486592    0.836071   14.526497
# min      0.000000     1.000000    0.000000    1.000000    0.420000
# 25%    222.500000   223.500000    0.000000    2.000000   20.125000
# 50%    445.000000   446.000000    0.000000    3.000000   28.000000
# 75%    667.500000   668.500000    1.000000    3.000000   38.000000
# max    890.000000   891.000000    1.000000    3.000000   80.000000
#
#             SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208
# std      1.102743    0.806057   49.693429
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.910400
# 50%      0.000000    0.000000   14.454200
# 75%      1.000000    0.000000   31.000000
# max      8.000000    6.000000  512.329200

# %%
# information of the df
df.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                        Graham, Miss Margaret Edith  female  19.0      0
# 888            Johnston, Miss Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 13 columns]>

# %%
# list csv columns
df.columns
# Out:
# Index(['Unnamed: 0', 'PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# You can drop some unnecessary columns using df.drop()
df.drop(columns="Sex")
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                                Heikkinen, Miss Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# 886                              Montvila, Rev. Juozas  27.0      0      0
# 887                        Graham, Miss Margaret Edith  19.0      0      0
# 888            Johnston, Miss Catherine Helen "Carrie"   NaN      1      2
# 889                              Behr, Mr. Karl Howell  26.0      0      0
# 890                                Dooley, Mr. Patrick  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# 3              113803  53.1000  C123        S
# 4              373450   8.0500   NaN        S
# ..                ...      ...   ...      ...
# 886            211536  13.0000   NaN        S
# 887            112053  30.0000   B42        S
# 888        W./C. 6607  23.4500   NaN        S
# 889            111369  30.0000  C148        C
# 890            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# check the lenght of the df
len(df)
# Out:
# 891

# %%
# Creating a subset of the df
name_sex = df.iloc[1:10, 4:7]
name_sex
# Out:
#                                                 Name     Sex   Age
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                              Heikkinen, Miss Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                      Palsson, Master Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
# accessing rows by spedifing the rows number with all the columns
new_coumn_name = df.loc[[3,4,8]]
new_coumn_name
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 3           3            4         1       1
# 4           4            5         0       3
# 8           8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch  Ticket     Fare Cabin Embarked
# 3      0  113803  53.1000  C123        S
# 4      0  373450   8.0500   NaN        S
# 8      2  347742  11.1333   NaN        S

# %%
# accessing rows by specifying rows numbers and specific columns by specifying column name
new_coumn_name = df.loc[[3,4,8], ['Name', 'Sex', "Age"]]
new_coumn_name
# Out:
#                                                 Name     Sex   Age
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0

# %%
# Check the data types of all the columns
df.dtypes
# Out:
# Unnamed: 0       int64
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# checking the specific column data type
df.Parch.dtypes
# Out:
# dtype('int64')

# %%
# return columns with specific data types
df.select_dtypes(include="int64")
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  SibSp  Parch
# 0             0            1         0       3      1      0
# 1             1            2         1       1      1      0
# 2             2            3         1       3      0      0
# 3             3            4         1       1      1      0
# 4             4            5         0       3      0      0
# ..          ...          ...       ...     ...    ...    ...
# 886         886          887         0       2      0      0
# 887         887          888         1       1      0      0
# 888         888          889         0       3      1      2
# 889         889          890         1       1      0      0
# 890         890          891         0       3      0      0
#
# [891 rows x 6 columns]

# %%
df.select_dtypes(include='object')
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                        Graham, Miss Margaret Edith  female
# 888            Johnston, Miss Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 886            211536   NaN        S
# 887            112053   B42        S
# 888        W./C. 6607   NaN        S
# 889            111369  C148        C
# 890            370376   NaN        Q
#
# [891 rows x 5 columns]

# %%
df.select_dtypes(exclude='object')
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0             0            1         0       3  22.0      1      0   7.2500
# 1             1            2         1       1  38.0      1      0  71.2833
# 2             2            3         1       3  26.0      0      0   7.9250
# 3             3            4         1       1  35.0      1      0  53.1000
# 4             4            5         0       3  35.0      0      0   8.0500
# ..          ...          ...       ...     ...   ...    ...    ...      ...
# 886         886          887         0       2  27.0      0      0  13.0000
# 887         887          888         1       1  19.0      0      0  30.0000
# 888         888          889         0       3   NaN      1      2  23.4500
# 889         889          890         1       1  26.0      0      0  30.0000
# 890         890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 8 columns]

# %%
df.select_dtypes(exclude='int64')
# Out:
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                                Heikkinen, Miss Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                        Graham, Miss Margaret Edith  female  19.0
# 888            Johnston, Miss Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# 3              113803  53.1000  C123        S
# 4              373450   8.0500   NaN        S
# ..                ...      ...   ...      ...
# 886            211536  13.0000   NaN        S
# 887            112053  30.0000   B42        S
# 888        W./C. 6607  23.4500   NaN        S
# 889            111369  30.0000  C148        C
# 890            370376   7.7500   NaN        Q
#
# [891 rows x 7 columns]

# %%
# insert a new column in the df
import numpy as np

# random data with the size of the df 
random_col = np.random.randint(10, 100, size=len(df))
print(random_col)

df.insert(3, "added new col", random_col)
# Out:
# [21 85 38 46 81 33 81 52 68 88 38 32 14 13 59 70 95 81 38 29 48 59 50 54
#  23 54 61 19 75 48 75 45 67 40 38 43 65 68 99 73 79 38 44 53 27 31 37 71
#  29 38 90 14 97 25 84 67 36 82 42 84 30 52 25 48 39 56 62 93 58 64 23 17
#  70 96 69 30 99 50 77 83 53 25 73 84 91 97 11 49 94 68 88 34 28 37 84 55
#  21 90 85 63 24 57 16 60 32 86 76 29 70 23 43 45 37 10 56 31 76 24 49 78
#  89 15 44 74 68 53 66 81 32 41 24 66 64 16 54 69 99 86 19 97 39 25 27 92
#  50 33 55 76 84 48 80 60 11 38 47 88 31 84 59 13 70 67 53 64 67 95 85 82
#  33 86 73 20 55 23 82 28 99 75 13 34 86 51 59 21 74 20 29 66 47 51 60 68
#  52 51 60 10 77 17 73 77 53 19 26 59 12 25 88 99 76 96 52 46 36 19 34 71
#  33 17 17 27 61 52 62 23 19 18 36 52 76 58 54 47 34 28 84 98 89 56 14 69
#  80 68 46 65 21 98 96 98 95 34 18 56 19 27 88 33 94 28 47 91 13 23 49 58
#  27 60 92 41 87 76 24 99 33 41 68 79 41 64 65 35 48 56 86 42 35 39 20 91
#  70 91 76 20 22 92 27 79 53 60 86 52 39 98 41 47 20 76 86 15 29 61 38 37
#  20 51 43 60 46 14 15 30 73 69 34 18 82 94 51 73 88 52 39 43 63 51 16 56
#  36 97 82 60 57 42 82 87 71 52 41 50 93 45 79 42 25 57 81 73 85 41 48 44
#  99 94 32 24 19 29 22 85 19 43 78 23 99 78 52 82 77 22 46 98 28 94 61 96
#  88 76 81 99 50 40 60 44 28 69 21 76 88 41 65 91 99 45 75 88 41 80 56 81
#  61 86 44 98 50 22 23 19 89 28 12 69 47 78 17 61 66 10 76 41 35 90 60 46
#  92 51 89 33 51 34 99 60 44 30 83 67 59 19 13 53 59 41 35 35 88 82 36 41
#  82 44 27 92 85 63 50 89 18 79 82 67 70 22 72 88 77 81 51 39 40 35 95 48
#  27 13 52 86 90 27 36 33 64 62 46 54 18 19 37 92 59 63 13 98 36 80 71 18
#  89 93 86 81 36 76 81 59 73 41 86 59 29 59 86 86 31 82 18 12 45 76 75 57
#  15 51 34 65 18 95 63 34 47 66 55 69 15 56 56 47 50 69 98 95 37 74 80 62
#  73 21 58 36 30 13 31 22 35 90 51 87 38 70 72 96 92 90 19 89 62 10 88 96
#  91 34 75 44 17 84 50 62 89 37 98 55 56 84 82 51 54 76 33 29 57 32 78 17
#  67 83 43 97 79 15 78 34 92 98 11 35 45 96 55 12 62 34 12 91 41 76 22 34
#  19 48 30 22 46 67 79 13 66 92 32 26 34 80 46 89 93 33 55 88 91 30 23 72
#  69 40 80 62 28 18 99 42 66 78 96 17 41 71 18 31 69 44 62 18 35 80 52 78
#  69 91 61 80 73 36 97 86 64 93 11 39 17 30 10 35 66 38 80 86 78 23 27 61
#  61 39 57 90 58 41 84 50 43 85 80 98 56 47 28 31 77 75 25 24 20 16 11 67
#  93 95 94 37 56 92 25 95 84 71 96 24 17 84 95 43 95 71 42 39 70 79 93 98
#  92 56 76 34 92 83 40 25 10 59 57 50 83 79 74 95 44 47 72 30 73 59 20 91
#  86 89 61 61 31 88 31 15 35 40 42 83 42 56 17 62 58 41 34 95 79 81 70 77
#  84 25 74 36 34 32 59 13 14 51 85 16 53 77 90 26 69 97 63 55 84 70 64 13
#  75 66 96 27 65 31 73 75 27 96 37 58 58 84 29 72 66 38 91 36 95 44 84 12
#  93 38 67 67 20 37 25 33 12 81 51 54 72 93 62 48 34 30 43 15 85 35 78 42
#  13 92 93 11 72 16 13 54 34 67 87 48 60 38 35 83 65 34 17 62 36 73 42 81
#  80 89 25]

# %%
# header of the df
df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  added new col  Pclass  \
# 0           0            1         0             21       3
# 1           1            2         1             85       1
# 2           2            3         1             38       3
# 3           3            4         1             46       1
# 4           4            5         0             81       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Cumulatives of the columns 
df[['Age', 'added new col']].cumsum()
# Out:
#           Age  added new col
# 0       22.00             21
# 1       60.00            106
# 2       86.00            144
# 3      121.00            190
# 4      156.00            271
# ..        ...            ...
# 886  21128.17          49463
# 887  21147.17          49544
# 888       NaN          49624
# 889  21173.17          49713
# 890  21205.17          49738
#
# [891 rows x 2 columns]

# %%
# sample method subset a rendom N'th rows to make operation easy
df.sample(n=3)
# Out:
#      Unnamed: 0  PassengerId  Survived  added new col  Pclass  \
# 25           25           26         1             54       3
# 529         529          530         0             51       2
# 727         727          728         1             95       3
#
#                                                   Name     Sex   Age  SibSp  \
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 529                        Hocking, Mr. Richard George    male  23.0      2
# 727                            Mannion, Miss Margareth  female   NaN      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 25       5  347077  31.3875   NaN        S
# 529      1   29104  11.5000   NaN        S
# 727      0   36866   7.7375   NaN        Q

# %%
# numerical quarry for a column
df['added new col'].where(df["added new col"] > 50)
# Out:
# 0       NaN
# 1      85.0
# 2       NaN
# 3       NaN
# 4      81.0
#        ...
# 886     NaN
# 887    81.0
# 888    80.0
# 889    89.0
# 890     NaN
# Name: added new col, Length: 891, dtype: float64

# %%
# replace the NaN with 0
df['added new col'].where(df['added new col'] == 0, 000)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 886    0
# 887    0
# 888    0
# 889    0
# 890    0
# Name: added new col, Length: 891, dtype: int32

# %%
df
# Out:
#      Unnamed: 0  PassengerId  Survived  added new col  Pclass  \
# 0             0            1         0             21       3
# 1             1            2         1             85       1
# 2             2            3         1             38       3
# 3             3            4         1             46       1
# 4             4            5         0             81       3
# ..          ...          ...       ...            ...     ...
# 886         886          887         0             42       2
# 887         887          888         1             81       1
# 888         888          889         0             80       3
# 889         889          890         1             89       1
# 890         890          891         0             25       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                        Graham, Miss Margaret Edith  female  19.0      0
# 888            Johnston, Miss Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 14 columns]

# %%
# find unique value of a column
df["Fare"].unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
#         79.2   ,   6.75  ,  11.5   ,  36.75  ,   7.7958,  12.525 ,
#         66.6   ,   7.3125,  61.3792,   7.7333,  69.55  ,  16.1   ,
#         15.75  ,  20.525 ,  55.    ,  25.925 ,  33.5   ,  30.6958,
#         25.4667,  28.7125,   0.    ,  15.05  ,  39.    ,  22.025 ,
#         50.    ,   8.4042,   6.4958,  10.4625,  18.7875,  31.    ,
#        113.275 ,  27.    ,  76.2917,  90.    ,   9.35  ,  13.5   ,
#          7.55  ,  26.25  ,  12.275 ,   7.125 ,  52.5542,  20.2125,
#         86.5   , 512.3292,  79.65  , 153.4625, 135.6333,  19.5   ,
#         29.7   ,  77.9583,  20.25  ,  78.85  ,  91.0792,  12.875 ,
#          8.85  , 151.55  ,  30.5   ,  23.25  ,  12.35  , 110.8833,
#        108.9   ,  24.    ,  56.9292,  83.1583, 262.375 ,  14.    ,
#        164.8667, 134.5   ,   6.2375,  57.9792,  28.5   , 133.65  ,
#         15.9   ,   9.225 ,  35.    ,  75.25  ,  69.3   ,  55.4417,
#        211.5   ,   4.0125, 227.525 ,  15.7417,   7.7292,  12.    ,
#        120.    ,  12.65  ,  18.75  ,   6.8583,  32.5   ,   7.875 ,
#         14.4   ,  55.9   ,   8.1125,  81.8583,  19.2583,  19.9667,
#         89.1042,  38.5   ,   7.725 ,  13.7917,   9.8375,   7.0458,
#          7.5208,  12.2875,   9.5875,  49.5042,  78.2667,  15.1   ,
#          7.6292,  22.525 ,  26.2875,  59.4   ,   7.4958,  34.0208,
#         93.5   , 221.7792, 106.425 ,  49.5   ,  71.    ,  13.8625,
#          7.8292,  39.6   ,  17.4   ,  51.4792,  26.3875,  30.    ,
#         40.125 ,   8.7125,  15.    ,  33.    ,  42.4   ,  15.55  ,
#         65.    ,  32.3208,   7.0542,   8.4333,  25.5875,   9.8417,
#          8.1375,  10.1708, 211.3375,  57.    ,  13.4167,   7.7417,
#          9.4833,   7.7375,   8.3625,  23.45  ,  25.9292,   8.6833,
#          8.5167,   7.8875,  37.0042,   6.45  ,   6.95  ,   8.3   ,
#          6.4375,  39.4   ,  14.1083,  13.8583,  50.4958,   5.    ,
#          9.8458,  10.5167])

# %%
# nunique return a value. How many unique value is there
df["Name"].nunique()
# Out:
# 891

# %%
# return unique value of each column
df.nunique()
# Out:
# Unnamed: 0       891
# PassengerId      891
# Survived           2
# added new col     90
# Pclass             3
# Name             891
# Sex                2
# Age               88
# SibSp              7
# Parch              7
# Ticket           681
# Fare             248
# Cabin            147
# Embarked           3
# dtype: int64
