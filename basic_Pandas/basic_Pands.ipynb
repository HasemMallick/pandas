# %% [markdown]
# ## Basic of pandas

# %%
# import pandas
import pandas as pd

# %%
# Check pandas version 
print(pd.__version__)
# Out:
# 2.2.2

# %%
# create a dataset
dataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

# create a dataframe
df = pd.DataFrame(dataset)
df.shape
df.head()
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
# Read a csv file in Pandas
csv = pd.read_csv("titanic data.csv", delimiter=",")
csv
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
# csv file to DF
df = pd.DataFrame(csv)
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
# shpae of the DF
df.shape
# Out:
# (891, 13)

# %%
# heade of the DF
df.head(4)
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
# tial of of df
df.tail(4)
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                         Name     Sex   Age  SibSp  Parch  \
# 887              Graham, Miss Margaret Edith  female  19.0      0      0
# 888  Johnston, Miss Catherine Helen "Carrie"  female   NaN      1      2
# 889                    Behr, Mr. Karl Howell    male  26.0      0      0
# 890                      Dooley, Mr. Patrick    male  32.0      0      0
#
#          Ticket   Fare Cabin Embarked
# 887      112053  30.00   B42        S
# 888  W./C. 6607  23.45   NaN        S
# 889      111369  30.00  C148        C
# 890      370376   7.75   NaN        Q

# %%
# stat of the df
df.describe()
# Out:
#        Unnamed: 0  PassengerId    Survived      Pclass         Age  \
# count  891.000000   891.000000  891.000000  891.000000  714.000000
# mean   445.000000   446.000000    0.383838    2.308642   29.699118
# std    257.353842   257.353842    0.486592    0.836071   14.526497
# min      0.000000     1.000000    0.000000    1.000000    0.420000
# 25%    222.500000   223.500000    0.000000    2.000000   20.125000
# 50%    445.000000   446.000000    0.000000    3.000000   28.000000
# 75%    667.500000   668.500000    1.000000    3.000000   38.000000
# max    890.000000   891.000000    1.000000    3.000000   80.000000
#
#             SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208
# std      1.102743    0.806057   49.693429
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.910400
# 50%      0.000000    0.000000   14.454200
# 75%      1.000000    0.000000   31.000000
# ...

# %%
# information of the df
df.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# ...

# %%
# list csv columns
df.columns
# Out:
# Index(['Unnamed: 0', 'PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# You can drop some unnecessary columns using df.drop()
df.drop(columns="Sex")
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                                Heikkinen, Miss Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# ...

# %%
# check the lenght of the df
len(df)
# Out:
# 891

# %%
# Creating a subset of the df
name_sex = df.iloc[1:10, 4:7]
name_sex
# Out:
#                                                 Name     Sex   Age
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                              Heikkinen, Miss Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                      Palsson, Master Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
# accessing rows by spedifing the rows number with all the columns
new_coumn_name = df.loc[[3,4,8]]
new_coumn_name
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 3           3            4         1       1
# 4           4            5         0       3
# 8           8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch  Ticket     Fare Cabin Embarked
# 3      0  113803  53.1000  C123        S
# 4      0  373450   8.0500   NaN        S
# 8      2  347742  11.1333   NaN        S

# %%
# accessing rows by specifying rows numbers and specific columns by specifying column name
new_coumn_name = df.loc[[3,4,8], ['Name', 'Sex', "Age"]]
new_coumn_name
# Out:
#                                                 Name     Sex   Age
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0

# %%
# Check the data types of all the columns
df.dtypes
# Out:
# Unnamed: 0       int64
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# checking the specific column data type
df.Parch.dtypes
# Out:
# dtype('int64')

# %%
# return columns with specific data types
df.select_dtypes(include="int64")
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  SibSp  Parch
# 0             0            1         0       3      1      0
# 1             1            2         1       1      1      0
# 2             2            3         1       3      0      0
# 3             3            4         1       1      1      0
# 4             4            5         0       3      0      0
# ..          ...          ...       ...     ...    ...    ...
# 886         886          887         0       2      0      0
# 887         887          888         1       1      0      0
# 888         888          889         0       3      1      2
# 889         889          890         1       1      0      0
# 890         890          891         0       3      0      0
#
# [891 rows x 6 columns]

# %%
df.select_dtypes(include='object')
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                        Graham, Miss Margaret Edith  female
# 888            Johnston, Miss Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df.select_dtypes(exclude='object')
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0             0            1         0       3  22.0      1      0   7.2500
# 1             1            2         1       1  38.0      1      0  71.2833
# 2             2            3         1       3  26.0      0      0   7.9250
# 3             3            4         1       1  35.0      1      0  53.1000
# 4             4            5         0       3  35.0      0      0   8.0500
# ..          ...          ...       ...     ...   ...    ...    ...      ...
# 886         886          887         0       2  27.0      0      0  13.0000
# 887         887          888         1       1  19.0      0      0  30.0000
# 888         888          889         0       3   NaN      1      2  23.4500
# 889         889          890         1       1  26.0      0      0  30.0000
# 890         890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 8 columns]

# %%
df.select_dtypes(exclude='int64')
# Out:
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                                Heikkinen, Miss Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                        Graham, Miss Margaret Edith  female  19.0
# 888            Johnston, Miss Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# ...

# %%
# insert a new column in the df
import numpy as np

# random data with the size of the df 
random_col = np.random.randint(10, 100, size=len(df))
print(random_col)

df.insert(3, "added new col", random_col)
# Out:
# [61 30 33 76 58 15 75 91 10 46 80 64 69 56 47 55 31 89 13 94 20 13 57 59
#  96 84 81 88 25 36 77 51 27 83 35 60 96 92 83 56 76 87 61 32 85 45 86 29
#  78 47 61 58 97 59 43 80 15 36 36 31 93 86 92 67 65 34 25 83 11 49 86 56
#  52 42 16 69 65 59 44 65 74 60 69 59 14 78 37 86 72 80 62 68 90 97 50 42
#  79 55 54 25 29 31 98 14 96 38 35 63 70 59 21 61 63 31 26 87 46 61 57 95
#  85 58 24 51 59 98 10 33 45 71 28 27 51 26 23 59 33 41 55 83 88 63 13 38
#  62 84 51 39 51 69 34 86 54 17 33 86 63 91 91 45 45 77 46 81 80 12 64 51
#  25 54 27 61 24 65 24 72 41 33 23 33 89 39 28 25 93 30 53 44 72 26 67 61
#  25 80 29 14 71 81 15 59 42 79 17 49 21 59 54 31 12 30 96 69 67 74 76 84
#  68 60 78 86 13 90 58 94 36 41 15 47 44 45 91 48 57 53 41 92 79 71 23 25
#  80 54 60 14 35 80 66 42 19 16 23 83 52 14 26 52 71 49 49 75 71 19 61 42
#  71 35 96 19 54 46 25 42 76 93 27 81 62 58 45 26 39 72 73 13 27 81 71 50
#  38 10 17 23 43 45 67 95 72 47 91 50 35 41 89 14 54 65 53 50 15 75 14 99
# ...

# %%
# header of the df
df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  added new col  Pclass  \
# 0           0            1         0             13       3
# 1           1            2         1             28       1
# 2           2            3         1             34       3
# 3           3            4         1             85       1
# 4           4            5         0             92       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# ...

# %%
# Cumulatives of the columns 
df[['Age', 'added new col']].cumsum()
# Out:
#           Age  added new col
# 0       22.00             61
# 1       60.00             91
# 2       86.00            124
# 3      121.00            200
# 4      156.00            258
# ..        ...            ...
# 886  21128.17          48897
# 887  21147.17          48969
# 888       NaN          48981
# 889  21173.17          49002
# 890  21205.17          49032
#
# [891 rows x 2 columns]

# %%
# sample method subset a rendom N'th rows to make operation easy
df.sample(n=3)
# Out:
#      Unnamed: 0  PassengerId  Survived  added new col  Pclass  \
# 233         233          234         1             53       3
# 245         245          246         0             80       1
# 48           48           49         0             78       3
#
#                               Name     Sex   Age  SibSp  Parch  Ticket  \
# 233  Asplund, Miss Lillian Gertrud  female   5.0      4      2  347077
# 245    Minahan, Dr. William Edward    male  44.0      2      0   19928
# 48             Samaan, Mr. Youssef    male   NaN      2      0    2662
#
#         Fare Cabin Embarked
# 233  31.3875   NaN        S
# 245  90.0000   C78        Q
# 48   21.6792   NaN        C

# %%
# numerical quarry for a column
df['added new col'].where(df["added new col"] > 50)
# Out:
# 0      61.0
# 1       NaN
# 2       NaN
# 3      76.0
# 4      58.0
#        ...
# 886    84.0
# 887    72.0
# 888     NaN
# 889     NaN
# 890     NaN
# Name: added new col, Length: 891, dtype: float64

# %%
# replace the NaN with 0
df['added new col'].where(df['added new col'] == 0, 000)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 886    0
# 887    0
# 888    0
# 889    0
# 890    0
# Name: added new col, Length: 891, dtype: int32

# %%
df
# Out:
#      Unnamed: 0  PassengerId  Survived  added new col  Pclass  \
# 0             0            1         0             13       3
# 1             1            2         1             28       1
# 2             2            3         1             34       3
# 3             3            4         1             85       1
# 4             4            5         0             92       3
# ..          ...          ...       ...            ...     ...
# 886         886          887         0             10       2
# 887         887          888         1             90       1
# 888         888          889         0             75       3
# 889         889          890         1             81       1
# 890         890          891         0             56       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# ...

# %%
# find unique value of a column
df["Fare"].unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
# ...

# %%
# nunique return a value. How many unique value is there
df["Name"].nunique()
# Out:
# 891

# %%
# return unique value of each column
df.nunique()
# Out:
# Unnamed: 0       891
# PassengerId      891
# Survived           2
# added new col     90
# Pclass             3
# Name             891
# Sex                2
# Age               88
# SibSp              7
# Parch              7
# Ticket           681
# Fare             248
# Cabin            147
# Embarked           3
# dtype: int64
